# %%
# !conda info --envs
# !nvidia-smi
# Out:
# # conda environments:
# #
# base                     /home/sunghyunahn/anaconda3
# adwg                     /home/sunghyunahn/anaconda3/envs/adwg
# dvaa                  *  /home/sunghyunahn/anaconda3/envs/dvaa
# unetr_pp                 /home/sunghyunahn/anaconda3/envs/unetr_pp
#
# Mon Oct  2 18:06:36 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 465.19.01    CUDA Version: 11.3     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:61:00.0 Off |                  N/A |
# ...

# %% [markdown]
# Generator

# %%
# !python /home/sunghyunahn/lecture_TA/Frame-Prediction/model/generator.py
# Out:
# cuda
# --------------------------------------------------------------------------
#       Layer (type)           Output Shape         Param #     Tr. Param #
# ...
#           inconv-1      [4, 64, 256, 256]          44,032          44,032
#             down-2     [4, 128, 128, 128]         221,696         221,696
#             down-3       [4, 256, 64, 64]         885,760         885,760
#             down-4       [4, 512, 32, 32]       3,540,992       3,540,992
#               up-5       [4, 256, 64, 64]       2,295,040       2,295,040
#               up-6     [4, 128, 128, 128]         574,080         574,080
#               up-7      [4, 64, 256, 256]         143,680         143,680
#           Conv2d-8       [4, 3, 256, 256]           1,731           1,731
# ...
# Total params: 7,707,011
# Trainable params: 7,707,011
# Non-trainable params: 0
# --------------------------------------------------------------------------
# input: torch.Size([4, 12, 256, 256])
# ...

# %% [markdown]
# Discriminator

# %%
# !python /home/sunghyunahn/lecture_TA/Frame-Prediction/model/discriminator.py
# Out:
# cuda
# --------------------------------------------------------------------------
#       Layer (type)           Output Shape         Param #     Tr. Param #
# ...
#           Conv2d-1     [4, 128, 128, 128]           6,272           6,272
#        LeakyReLU-2     [4, 128, 128, 128]               0               0
#           Conv2d-3       [4, 256, 64, 64]         524,544         524,544
#        LeakyReLU-4       [4, 256, 64, 64]               0               0
#           Conv2d-5       [4, 512, 32, 32]       2,097,664       2,097,664
#        LeakyReLU-6       [4, 512, 32, 32]               0               0
#           Conv2d-7       [4, 512, 31, 31]       4,194,816       4,194,816
#        LeakyReLU-8       [4, 512, 31, 31]               0               0
#           Conv2d-9         [4, 1, 30, 30]           8,193           8,193
# ...
# Total params: 6,831,489
# Trainable params: 6,831,489
# Non-trainable params: 0
# ...
